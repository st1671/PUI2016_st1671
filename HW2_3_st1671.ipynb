# %%
import os
import numpy as np
from numpy.random import randn
import pylab as pl

from pandas import Series, DataFrame
import pandas
import pandas as pd

DFdata = os.getenv('DFDATA')
print(DFdata)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
df_energy = pd.read_csv(DFdata+"/5gde-fmj3/1414246119/5gde-fmj3")

# %%
# %pylab inline

#np.set_printoptions(precision=10, threshold=500)
np.random.seed(123321)
pl.rc('figure', figsize=(10, 6))
pd.options.display.max_rows = 10
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_energy.head(n=10)
# Out:
#           BBL Street Number       Street Name    Borough    Zip  \
# 0  1000010010             1  GOVERNORS ISLAND  MANHATTAN  10004
# 1  1000020002           NaN   MARGINAL STREET  MANHATTAN  10004
# 2  1000047501             1      WATER STREET  MANHATTAN  10004
# 3  1000057501           125      BROAD STREET  MANHATTAN  10004
# 4  1003620001           134          AVENUE D  MANHATTAN  10009
# 5  1000090001            34  WHITEHALL STREET  MANHATTAN  10004
# 6  1000090014            17      STATE STREET  MANHATTAN  10004
# 7  1000090029            24  WHITEHALL STREET  MANHATTAN  10004
# 8  1000100014            33  WHITEHALL STREET  MANHATTAN  10004
# 9  1000100016            90      BROAD STREET  MANHATTAN  10004
#
#    Benchmarking Submission  Entry Number  Site EUI(kBtu/ft2)  \
# 0  No Record as of 08/1/13           NaN                 NaN
# 1  No Record as of 08/1/13           NaN                 NaN
# 2                      Yes          41.0               102.0
# ...

# %%
df_energy.drop(['BBL', 'Street Number', 'Street Name', 'Borough' ,'Zip'], axis=1, inplace=True)
df_energy.drop(['Benchmarking Submission', 'Entry Number'] ,axis=1, inplace=True)
df_energy.drop(['Indoor Water Intensity (All Water Sources)(gal/ft2)','Reported Water Method'],axis=1, inplace=True)
df_energy.drop(['ENERGY STAR Score','Total GHG Emissions(MtCO2e)'],axis=1, inplace=True)
df_energy.drop(['Property Floor Area (Buildngs and Parking)(ft2)','Reported BINs'],axis=1, inplace=True)
df_energy.drop(['Primary Property Type - Self Selected','Number of Buildings'],axis=1, inplace=True)

# %%
df_energy.head(n=10)
# Out:
#    Site EUI(kBtu/ft2)  Weather Normalized Source EUI(kBtu/ft2)
# 0                 NaN                                      NaN
# 1                 NaN                                      NaN
# 2               102.0                                    287.9
# 3               119.6                                    261.5
# 4                30.3                                     85.7
# 5                99.5                                    302.6
# 6                79.7                                    210.0
# 7               139.4                                    295.2
# 8               134.5                                    432.9
# 9                39.8                                    118.2

# %%
df_energy.plot(kind='scatter', x='Site EUI(kBtu/ft2)', y='Weather Normalized Source EUI(kBtu/ft2)',figsize=(6, 4))
